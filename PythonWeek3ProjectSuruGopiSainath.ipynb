# %% [markdown]
# # **Python Week 3 Project by Suru Gopi Sainath**
# - Dataset used: https://www.kaggle.com/datasets/dmitrynikolaev/youtube-dislikes-dataset
# ---

# %% [markdown]
# # 1Q. Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top 5 and bottom 5 records.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# numpy is a library,which we can use for operations on numerical data.
# pandas is a library, which is upgrade of numpy library. Using pandas we can do operations on tabular data as well.

# %%
data_df=pd.read_csv('youtube_dislike_dataset.csv')
data_df
# Out:
#           video_id                                              title
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals  \
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at
# ...

# %%
print("\n Top 5 records : ")
data_df.head()

# By default data_df.head() gives top 5 records, without giving number in head method.
# Out:
#  Top 5 records :
#       video_id                                       title
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals  \
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00  \
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count
# 0     1048888   19515       226           1319  \
# 1    15352638  359277      7479          18729
# ...

# %%
print("\n Bottom 5 records : ")
data_df.tail()

# By default data_df.tail() gives bottom 5 records, without giving number in tail method.
# Out:
#  Bottom 5 records :
#           video_id                                              title
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...  \
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49  \
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count
# ...

# %% [markdown]
# # 2Q. Check the info of the dataframe and write your inferences on data types and shape of the dataset.

# %%
data_df.info()

#Above code gives total information of dataframe like datatypes of all columns, number of columns and number of rows.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %% [markdown]
# ## **<font color="blue">Inferences:</font>**
# * There are 12 columns and 37422 rown in this dataframe.
# * In this dataframe, 8 columns(video_id, title, channel_id, channel_title, published_at, tags, description, comments) are 'object' datatype and 4 columns(view_count, likes, dislikes, comment_count) are 'int' datatype.
# * These 4 'int' datatype columns are numerical valued columns and 8 'object' datatype columns are string format and date format columns.

# %% [markdown]
# # 3Q. Check for the Percentage of the missing values and drop or impute them.

# %%
Missing_values_percentage = round(((data_df.isna().sum()/len(data_df))*100),2)
print(Missing_values_percentage)

# Here, data_df.isna().sum() gives count of all missing values in there respective columns.
# (data_df.isna().sum()/len(data_df))*100 gives percentage of missing values to the total count of column.
# Out:
# video_id         0.00
# title            0.00
# channel_id       0.00
# channel_title    0.00
# published_at     0.00
# view_count       0.00
# likes            0.00
# dislikes         0.00
# comment_count    0.00
# tags             0.00
# description      0.00
# comments         0.42
# dtype: float64

# %%
# By the above output, we can say that there is no missing values in 11 columns.
# Only 1 column that is "comments" column has 0.42 % missing values in it.
# As it's a very less percentage of missing values, we can impute them.
# There is no importance of comments data in next questions but if we drop all rows having missing values in comments,
# leads to loss of useful information of other columns which may useful in next questions.
# So, we impute missing values of 'comments' as " " (empty) using .fillna() method.

data_df1 = data_df.fillna(" ")
data_df1.isna().sum()

# we can see below output that there is no more missing values in any column.
# Out:
# video_id         0
# title            0
# channel_id       0
# channel_title    0
# published_at     0
# view_count       0
# likes            0
# dislikes         0
# comment_count    0
# tags             0
# description      0
# comments         0
# dtype: int64

# %% [markdown]
# # 4Q. Check the statistical summary of both numerical and categorical columns and write your inferences.

# %%
data_df1.describe(exclude='object')

# In .describe() method, when we use exclude='object',
# it just gives statistical summary of numerical columns whose datatype is not object.
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.742200e+04  3.742200e+04  3.742200e+04   3.742200e+04
# mean   5.697838e+06  1.668147e+05  4.989862e+03   9.924930e+03
# std    2.426622e+07  5.375670e+05  3.070824e+04   1.171003e+05
# min    2.036800e+04  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    5.122970e+05  1.323350e+04  2.810000e+02   9.000000e+02
# 50%    1.319078e+06  4.233050e+04  7.960000e+02   2.328000e+03
# 75%    3.670231e+06  1.304698e+05  2.461750e+03   6.184000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %% [markdown]
# ## **<font color="blue">Inferences:</font>**
# * In numerical columns, count of all columns showing as 37,422 records.
# * Mean is a measure of central tendency in the data.
# * STD(standard deviation), min and max are measures of dispersion of the data.
# * 25%, 50% and 75% are percentiles(quantiles) of the data.
# * Mean,std,min,max,25%, 50% and 75% values are higher for view_count column only.

# %%
data_df1.describe(include='object')

# In .describe() method, when we use include='object',
# it just gives statistical summary of categorical columns whose datatype is object.
# Out:
#            video_id  title                channel_id        channel_title
# count         37422  37422                     37422                37422  \
# unique        37422  37113                     10961                10883
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
#
#                published_at   tags description comments
# count                 37422  37422       37422    37422
# unique                36772  28799       35630    37265
# top     2020-10-16 04:00:10
# freq                      6   3817         589      158

# %% [markdown]
# ## **<font color="blue">Inferences:</font>**
# * In categorical columns, statistical summary is count, unique, top and freq.
# * count of all records in categorical columns are equal.
# * Highest number of unique values is there in video_id and comments column.
# * Least number of unique values there in channel_title column.
# * top is the most common value in the column.
# * freq is the frequency of most common value in the column.

# %% [markdown]
# # 5Q. Convert datatype of column published_at from object to pandas datetime.

# %%
data_df1['published_at'] = pd.to_datetime(data_df1['published_at'])

# we use pd.to_datetime() method to convert 'published_at' column datatype from 'object' to pandas 'datetime' datatype.

# %%
data_df1.dtypes

# from below output we can say that 'published_at' column converted to 'datetime' datatype.
# Out:
# video_id                 object
# title                    object
# channel_id               object
# channel_title            object
# published_at     datetime64[ns]
# view_count                int64
# likes                     int64
# dislikes                  int64
# comment_count             int64
# tags                     object
# description              object
# comments                 object
# dtype: object

# %% [markdown]
# # 6Q. Create a new column as 'published_month' using the column published_at (display the months only)

# %%
data_df1['published_month'] = data_df1['published_at'].dt.month
print(data_df1['published_month'])

# here 'published_at' column is datetime datatype, so we have a method .dt.month in it to extract month.
# from below output we can say that new column 'published_month' is created and had the values of months of 'published_at' column.
# Out:
# 0         7
# 1         6
# 2         9
# 3         3
# 4        12
#          ..
# 37417     2
# 37418     1
# 37419     6
# 37420    10
# 37421     5
# Name: published_month, Length: 37422, dtype: int32

# %% [markdown]
# # 7Q. Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb' and so on.....

# %%
month_dict={1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',7:'Jul',8:'Aug',9:'Sep',10:'Oct',11:'Nov',12:'Dec'}
data_df1['published_month'].replace(month_dict,inplace=True)
print(data_df1['published_month'])

# we used 'month_dict' dictionary to declare month names with respect to there number.
# by using .replace method we replaced 'published_month' column from number to there respective month name.
# in below output we can see that numbers replaced with month names to whole 'published_month' column.
# Out:
# 0        Jul
# 1        Jun
# 2        Sep
# 3        Mar
# 4        Dec
#         ...
# 37417    Feb
# 37418    Jan
# 37419    Jun
# 37420    Oct
# 37421    May
# Name: published_month, Length: 37422, dtype: object

# %% [markdown]
# # 8Q. Find the number of videos published each month and arrange the months in a decreasing order based on the video count.

# %%
data_df1.groupby('published_month')['video_id'].count().to_frame().sort_values(by='video_id',ascending=False)

# we grouped 'published_month' with count of 'video_id' and sorted in decreasing order of count of 'video_id'
# Out:
#                  video_id
# published_month
# Oct                  4991
# Sep                  4880
# Nov                  4851
# Aug                  4262
# Dec                  3072
# Jul                  2340
# Jun                  2316
# Mar                  2258
# Feb                  2137
# Apr                  2126
# Jan                  2108
# May                  2081

# %% [markdown]
# # 9Q. Find the count of unique video_id, channel_id and channel_title.

# %%
print("count of unique video_id : ",data_df1['video_id'].nunique())
print("count of unique channel_id : ",data_df1['channel_id'].nunique())
print("count of unique channel_title : ",data_df1['channel_title'].nunique())

# used .nunique() method to extract count of unique values
# Out:
# count of unique video_id :  37422
# count of unique channel_id :  10961
# count of unique channel_title :  10883

# %% [markdown]
# # 10Q. Find the top10 channel names having the highest number of videos in the dataset and the bottom10 having lowest number of videos.

# %%
print("\n top 10 channel names having highest number of videos are: ")
data_df1.groupby('channel_title')['video_id'].count().to_frame().sort_values(by='video_id',ascending=False).head(10)

# used .groupby method to group 'channel_title' with count of 'video_id' and sorted in decreasing order of count of 'video_id'
# and extracted top 10 records using .head method
# Out:
#  top 10 channel names having highest number of videos are:
#                      video_id
# channel_title
# Sky Sports Football       533
# The United Stand          301
# BT Sport                  246
# NBA                       209
# NFL                       162
# WWE                       122
# SSSniperWolf               99
# SSundee                    98
# FORMULA 1                  87
# NHL                        86

# %%
print("\n bottom 10 channel names having lowest number of videos are: ")
data_df1.groupby('channel_title')['video_id'].count().to_frame().sort_values(by='video_id',ascending=False).tail(10)

# used .groupby method to group 'channel_title' with count of 'video_id' and sorted in decreasing order of count of 'video_id'
# and extracted bottom 10 records using .tail method
# Out:
#  bottom 10 channel names having lowest number of videos are:
#                 video_id
# channel_title
# Karchez                1
# Karate Combat          1
# Kaptain Kuba           1
# Kanye West             1
# Kannur kitchen         1
# Kannada Cinema         1
# KanalD                 1
# Kanak News             1
# Kamille Ramos          1
# zoom                   1

# %% [markdown]
# # 11Q. Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.

# %%
print("\n title of the video which has the maximum number of likes is:")
data_df1.groupby('title')['likes'].max().to_frame().sort_values(by='likes',ascending=False).head(1)

# used .groupby method to group 'title' with max of 'likes' and sorted in decreasing order of max of 'likes'
# and extracted maximum liked video title using .head method
# Out:
#  title of the video which has the maximum number of likes is:
#                                   likes
# title
# BTS () 'Dynamite' Official MV  31837675

# %%
print("\n title of the video having minimum likes is:")
data_df1.groupby('title')['likes'].min().to_frame().sort_values(by='likes',ascending=True).head(1)

# used .groupby method to group 'title' with min of 'likes' and sorted in increasing order of min of 'likes'
# and extracted minimum liked video title using .head method
# Out:
#  title of the video having minimum likes is:
#                                                     likes
# title
# Kim Kardashian's Must-See Moments on "Saturday ...      0

# %% [markdown]
# ## **<font color="blue">Inferences:</font>**
# * title of the video which has the maximum number of likes is "BTS () 'Dynamite' Official MV" with likes of "31837675"
# * title of the video having minimum likes is "Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News" with likes of "0"

# %% [markdown]
# # 12Q. Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences.

# %%
print("\n title of the video which has the maximum number of dislikes is:")
data_df1.groupby('title')['dislikes'].max().to_frame().sort_values(by='dislikes',ascending=False).head(1)

# used .groupby method to group 'title' with max of 'dislikes' and sorted in decreasing order of max of 'dislikes'
# and extracted maximum disliked video title using .head method
# Out:
#  title of the video which has the maximum number of dislikes is:
#                                      dislikes
# title
# Cuties | Official Trailer | Netflix   2397733

# %%
print("\n title of the video which has the minimum number of dislikes is:")
data_df1.groupby('title')['dislikes'].min().to_frame().sort_values(by='dislikes',ascending=True).head(1)

# used .groupby method to group 'title' with min of 'dislikes' and sorted in increasing order of min of 'dislikes'
# and extracted minimum disliked video title using .head method
# Out:
#  title of the video which has the minimum number of dislikes is:
#                                                     dislikes
# title
# Kim Kardashian's Must-See Moments on "Saturday ...         0

# %% [markdown]
# ## **<font color="blue">Inferences:</font>**
# * title of the video which has the maximum number of dislikes is "Cuties | Official Trailer | Netflix" with dislikes of "2397733"
# * title of the video which has the minimum number of dislikes is "Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News" with dislikes of "0"

# %% [markdown]
# # 13Q. Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.

# %%
Correlation=data_df1['view_count'].corr(data_df1['dislikes'])
print("\n correlation between view_count and dislikes is:  ",round(Correlation,2),"\n")

# used .corr method to see correlation between 'view_count','dislikes'.
# Out:
#  correlation between view_count and dislikes is:   0.68

# %%
plt.scatter(data_df1['view_count'],data_df1['dislikes'],c='b')
plt.title("\n Scatter plot of view_count,dislikes \n")
plt.xlabel('view_count')
plt.ylabel('dislikes')
plt.show()

# used matplotlib.pyplot to plot a scatter plot.
# scatter plot explains correlation between 2 variables.

# %% [markdown]
# ## **<font color="blue">Inferences:</font>**
# * Correlation is mutual relationship between 2 columns.
# * Here, correlation between view_count, dislikes is 0.68.
# * As it is 0.68, we can conclude that there is positive correlation between view_count,dislikes.
# * that means, if view_count value increases, dislikes value also increases.
# * if view_count value decreases, dislikes value also decreases.
# * Here in scatter plot, we can easily see that as view_count values increases, dislikes values also increasing.

# %% [markdown]
# # 14Q. Display all the information about the videos that were published in January, and mention the count of videos that were published in January.

# %%
Jan_data_df=data_df1[data_df1['published_month'] == 'Jan']
Jan_data_df
# Out:
#           video_id                                              title
# 27     -2Gwm7QfBnE                                    Q&A With Naisha  \
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at
# ...

# %%
Jan_data_df.describe()
# Out:
#                         published_at    view_count         likes
# count                           2108  2.108000e+03  2.108000e+03  \
# mean   2021-01-17 11:32:44.133301504  4.976449e+06  1.315030e+05
# min              2021-01-01 00:00:54  2.845000e+04  2.800000e+01
# 25%    2021-01-09 22:42:18.750000128  4.322335e+05  1.032400e+04
# 50%              2021-01-17 18:35:30  1.147500e+06  3.173900e+04
# 75%    2021-01-25 14:00:07.750000128  3.227483e+06  1.076512e+05
# max              2021-01-31 23:15:09  6.203274e+08  7.828036e+06
# std                              NaN  2.055331e+07  3.886887e+05
#
#             dislikes  comment_count
# count    2108.000000   2.108000e+03
# mean     3614.568311   8.923385e+03
# min         3.000000   0.000000e+00
# 25%       249.000000   8.747500e+02
# 50%       729.000000   2.328500e+03
# 75%      2243.250000   6.302000e+03
# max    409144.000000   1.095119e+06
# std     13946.711333   3.664662e+04

# %%
Jan_data_df.describe(include='object')
# Out:
#            video_id     title                channel_id        channel_title
# count          2108      2108                      2108                 2108  \
# unique         2108      2106                      1436                 1433
# top     -2Gwm7QfBnE  YouTuber  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1         2                        49                   49
#
#         tags description comments published_month
# count   2108        2108     2108            2108
# unique  1814        2051     2100               1
# top                                           Jan
# freq     169          22        9            2108

# %%
Jan_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2108 entries, 27 to 37418
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   video_id         2108 non-null   object
#  1   title            2108 non-null   object
#  2   channel_id       2108 non-null   object
#  3   channel_title    2108 non-null   object
#  4   published_at     2108 non-null   datetime64[ns]
#  5   view_count       2108 non-null   int64
#  6   likes            2108 non-null   int64
#  7   dislikes         2108 non-null   int64
#  8   comment_count    2108 non-null   int64
#  9   tags             2108 non-null   object
#  10  description      2108 non-null   object
#  11  comments         2108 non-null   object
#  12  published_month  2108 non-null   object
# dtypes: datetime64[ns](1), int64(4), object(8)
# memory usage: 230.6+ KB

# %%
print("Count of total number of videos published in the month of january : ",Jan_data_df['video_id'].count())
# Out:
# Count of total number of videos published in the month of january :  2108
